# %% [markdown]
# # Vanishing and exploding gradients | Deep Learning Tutorial 35 (Tensorflow, Keras & Python)
#
# **Vanishing gradient** is a commong problem encountered while training a **_deep neural network_** with many layers. In case of **RNN** this problem is prominent as <u>_unrolling a network layer_</u> in time makes it more like a **_deep neural network_** with many layers. In this video we will discuss what **vanishing and exploding gradients** are in **artificial neural network (ANN)** and in **recurrent neural network (RNN)**
#
#
# Credit: https://www.youtube.com/watch?v=qowp6SQ9_Oo&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=35
# #### Owner: Codebasics

# %% [markdown]
# # Regular ANN
# ![image.png](attachment:image.png)

# %% [markdown]
# # Train the ANN
# ![image.png](attachment:image.png)

# %% [markdown]
# # Actual output with predicted output and back propagation
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Loss calculation
# ![image.png](attachment:image.png)

# %% [markdown]
# # Gradient Descent & Learning Rate
# ![image.png](attachment:image.png)

# %% [markdown]
# # Vanishing Gradients
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Vanishing Gradient problem in RNN
# ![image.png](attachment:image.png)
#
# # Un-rolling of Neural Network in time
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Exploding Gradients
# ![image.png](attachment:image.png)

# %% [markdown]
# # Solution of Vanishing & Exploding Gradients
#
# ## Special type of RNN
#
# # GRU & LSTM
#
# ![image.png](attachment:image.png)
