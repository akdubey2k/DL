# %% [markdown]
# # Bidirectional RNN | Deep Learning Tutorial 38 (Tensorflow, Keras & Python)
# **Bi directional RNNs** are used in **NLP** problems where looking at what comes in the sentence after a given word influences final outcome. In this short video we will look at __bi directional RNN__ architecture using a very simple example of named entity recognition.
#
# Credit: https://www.youtube.com/watch?v=atYPhweJ7ao&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=38
# #### Owner: Codebasic

# %% [markdown]
# # Named Entity Recognition
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Simple RNN, single direction, left to right

# %% [markdown]
# # Acutal RNN Cell
# ![image-2.png](attachment:image-2.png)
#
# # Looping effect, un-rolls in time
# ![image.png](attachment:image.png)

# %% [markdown]
# # Remove all neuron, only cell available
# ![image.png](attachment:image.png)
#
# # Simple RNN, decide apple is friut or company?
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Same RNN cell but the activation is now going from right to left
# ![image.png](attachment:image.png)

# %% [markdown]
# # Decide whether apple is fruit or a company
# ![image.png](attachment:image.png)
#
# ## y^3 hat is the output of a1 & a2

# %% [markdown]
# # Bi-directional RNN, here y^3 hat have an influence of all the activation results from right to left
# ![image.png](attachment:image.png)
