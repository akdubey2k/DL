# %% [markdown]
# # Types of RNN | Recurrent Neural Network Types | Deep Learning Tutorial 34 (Tensorflow & Python)
#
# In this video we will discuss different types of **RNN** types such as,
# 1. One to many
# 2. Many to many
# 3. Many to one
#
# Credit: https://www.youtube.com/watch?v=EzsXi4WzelI&list=PLeo1K3hjS3uu7CxAacxVndI4bE_o3BDtO&index=34
#
# #### Owner: Codebasics

# %% [markdown]
# # Named Entity Recognition
# ![image.png](attachment:image.png)

# %% [markdown]
# # Many to Many RNN
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sentiment Analysis
# ![image.png](attachment:image.png)

# %% [markdown]
# # Many to One
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # One to Many

# %% [markdown]
# # Music Generation
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
